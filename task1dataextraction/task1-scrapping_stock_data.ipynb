# %%
import yfinance as yf
import pandas as pd

# %%
tickers = ['META', 'AMZN', 'AAPL', 'NFLX', 'GOOGL']

data = yf.download(tickers, start='2020-01-01', end='2024-01-01')
# Out:
# [*********************100%%**********************]  5 of 5 completed

# %%
data.head()
# Out:
# Price       Adj Close                                                \
# Ticker           AAPL       AMZN      GOOGL        META        NFLX
# Date
# 2020-01-02  72.960457  94.900497  68.433998  209.557648  329.809998
# 2020-01-03  72.251137  93.748497  68.075996  208.448837  325.899994
# 2020-01-06  72.826874  95.143997  69.890503  212.374680  335.829987
# 2020-01-07  72.484337  95.343002  69.755501  212.834183  330.750000
# 2020-01-08  73.650352  94.598503  70.251999  214.991898  339.260010
#
# Price           Close                                                ...  \
# Ticker           AAPL       AMZN      GOOGL        META        NFLX  ...
# Date                                                                 ...
# 2020-01-02  75.087502  94.900497  68.433998  209.779999  329.809998  ...
# 2020-01-03  74.357498  93.748497  68.075996  208.669998  325.899994  ...
# 2020-01-06  74.949997  95.143997  69.890503  212.600006  335.829987  ...
# ...

# %%
data.to_csv('faang_stock.csv')
